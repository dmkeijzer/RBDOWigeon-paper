# %%
import sys
sys.path.append('../')

import numpy as np
from Equilibrium import *
from constants import *
# from cg_est import *

# %%
fakes = {
       'config1': {
           'xcg': 2, 'acf': 0.5, 'acb': 3.5, 'mWing': mTO / 8, 'b': 11.2 / 2, 'DF': 1000, 'DB': 1000, 'TpE': 100, 'nE': 3
            },
       'config2': {
           'xcg': 2, 'acf': 0.5, 'acb': 3.5, 'mWing': mTO / 8, 'b': 11.2 / 2, 'DF': 800, 'DB': 800, 'TpE': 800 / 24, 'nE': 6
            },
       'config3': {
           'xcg': 2, 'acf': 0.5, 'acb': 3.5, 'mWing': mTO / 8, 'b': 11.2 / 2, 'DF': 800, 'DB': 800, 'TpE': 800 / 24, 'nE': 6
            }
        }
globals().update(fakes['config3'])

# %%
Weight = PointLoad([0, - mTO * 9.81, 0], [xcg, 0, 0])
LFront = PointLoad([0, 1, 0], [acf, 0, 0])
LBack = PointLoad([0, 1, 0], [acb, 0, 0])
motion = EquilibriumEquation(kloads = [Weight], ukloads=[LFront, LBack])
motion.SetupEquation()
LiftF, LiftB = motion.SolveEquation()
print(f'{LiftF, LiftB = }')
# Out:
# LiftF, LiftB = (9471.555000000002, 9471.555)

# %%
pos = np.linspace(0, b)
WingWeight = RunningLoad([[0]*len(pos), [- mWing * 9.81 / b]*len(pos)], pos, axis=2)
LiftDist = RunningLoad([[0]*len(pos), [LiftF / b] * len(pos)], pos, axis=2)
DragDist = RunningLoad([[DF / b] * len(pos), [0]*len(pos)], pos, axis=2)
Thrust = [PointLoad([-TpE, 0, 0], [0, 0, i]) for i in np.linspace(0, b, nE)]

Fixedx = PointLoad([1, 0, 0], [0, 0, 0])
Fixedy = PointLoad([0, 1, 0], [0, 0, 0])
Fixedz = PointLoad([0, 0, 1], [0, 0, 0])

FixedMomentx, FixedMomenty, FixedMomentz = Moment([1, 0, 0]), Moment([0, 1, 0]), Moment([0, 0, 1])

wingequation = EquilibriumEquation(kloads=[WingWeight, LiftDist, DragDist] + Thrust,
                                   ukloads=[Fixedx, Fixedy, Fixedz, FixedMomentx, FixedMomenty, FixedMomentz])
wingequation.SetupEquation()
print(Reactions := wingequation.SolveEquation())
# Out:
# [ -600.      -7103.66625     0.      19890.2655  -1680.          0.     ]

# %%
# C1: 
# C2: [ -600.      -7103.66625     0.      19890.2655  -1680.          0.     ]
